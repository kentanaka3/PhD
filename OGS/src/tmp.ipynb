# %%
import argparse
import ogsparser as OGS_P
import ogsconstants as OGS_C
from pathlib import Path
from datetime import datetime, timedelta as td
from matplotlib.path import Path as mplPath
args = {
  "-v": True,
  "-D": (datetime(2024, 3, 20), datetime(2024, 6, 20)),
  "-N": '/Users/admin/Desktop/OGS_Catalog/catalogs/OGSCatalog',
  "-f": "/Users/admin/Desktop/OGS_Catalog/OGS/data/manual/RSFVG-2024.hpl",
}
args = argparse.Namespace(
  ext='*',
  directory=None,
  file=[Path('/Users/admin/Desktop/Monica/PhD/data/manual/RSFVG-2023.dat'),
        Path('/Users/admin/Desktop/Monica/PhD/data/manual/RSFVG-2023.hpc'),
        Path('/Users/admin/Desktop/Monica/PhD/data/manual/RSFVG-2023.hpl'),
        Path('/Users/admin/Desktop/Monica/PhD/data/manual/RSFVG-2023.pun'),
        Path('/Users/admin/Desktop/Monica/PhD/data/manual/RSFVG-2023.txt'),
        Path('/Users/admin/Desktop/Monica/PhD/data/manual/RSFVG-2024.dat'),
        Path('/Users/admin/Desktop/Monica/PhD/data/manual/RSFVG-2024.hpc'),
        Path('/Users/admin/Desktop/Monica/PhD/data/manual/RSFVG-2024.hpl'),
        Path('/Users/admin/Desktop/Monica/PhD/data/manual/RSFVG-2024.pun'),
        Path('/Users/admin/Desktop/Monica/PhD/data/manual/RSFVG-2024.txt')],
        verbose=False,
        dates=[datetime(2024, 3, 20, 0, 0), datetime(2024, 6, 20, 0, 0)],
        name=Path('/Users/admin/Desktop/Monica/PhD/catalogs/OGSCatalog'),
        polygon=mplPath(OGS_C.OGS_POLY_REGION))
OGS_Catalog = OGS_P.DataCatalog(args)
# Out:
# Empty DataFrame
# Columns: [index, time, longitude, latitude, depth, MD, NO, DMIN, GAP, RMS, ERH, ERZ, QM, NOTES, GROUPS]
# Index: []
# Empty DataFrame
# Columns: [index, time, ERT, phase, NOTES, station, NETWORK, GROUPS]
# Index: []
# Figure saved to DAT2024OGSCatalogERT.png
#           index                    time  longitude  latitude  depth      MD  \
# 0    2024000393 2024-03-20 02:17:47.380    12.6913   46.3978   5.82    0.82
# 1    2024000395 2024-03-20 10:24:42.950    10.3242   46.3080   3.97    1.13
# 2    2024000396 2024-03-20 22:48:14.220    14.1768   45.8322  16.80    1.07
# 3    2024000397 2024-03-21 02:43:27.290    10.5970   46.0515   4.68    1.72
# 4    2024000398 2024-03-21 08:00:19.660    10.5405   46.7453  14.20    1.23
# ..          ...                     ...        ...       ...    ...     ...
# 441  2024000880 2024-06-20 13:40:05.190    10.2163   46.2243   7.00    0.87
# 442  2024000881 2024-06-20 14:58:26.770    12.7817   46.4187   3.28    1.29
# ...

# %%
import argparse
from pathlib import Path
from importlib import reload
from datetime import datetime

import ogscompare as OGS_A
args = argparse.Namespace(base=Path('/Users/admin/Desktop/OGS_Catalog/catalogs/OGSCatalog/.txt/events/2024'),
                          #base=Path('/Users/admin/Desktop/OGS_Catalog/catalogs/OGSCatalog/.dat/assignments/2024'),
                          #base=Path('/Users/admin/Desktop/OGS_Catalog/catalogs/OGSCatalog'),
                          dates=[datetime(2024, 3, 20, 0, 0), datetime(2024, 6, 20, 0, 0)],
                          station=Path('/Users/admin/Desktop/Monica/PhD/data/station'),
                          #target=Path('/Users/admin/Desktop/OGS_Catalog/catalogs/OGS/assignments.csv'),
                          target=Path('/Users/admin/Desktop/OGS_Catalog/catalogs/OGS/events.csv'),
                          #target=Path('/Users/admin/Desktop/OGS_Catalog/catalogs/OGS/NonLinLoc/events/'),
                          #target=Path('/Users/admin/Desktop/OGS_Catalog/catalogs/OGS/OGSMagnitude/events/'),
                          #target=Path('/Users/admin/Desktop/OGS_Catalog/catalogs/OGS/SeisBenchPicker/events/'),
                          #target=Path('/Users/admin/Desktop/OGS_Catalog/catalogs/OGS/GammaAssociator/events/'),
                          #target=Path('/Users/admin/Desktop/OGS_Catalog/catalogs/OGS/PyOctoAssociator/events/'),
                          waveform=Path('/Volumes/Expansion/KEN/waveforms'),
                          verbose=True)

# %%
reload(OGS_A)
print(args.base)
BaseCatalog = OGS_A.Base(args.base, args)
print(BaseCatalog.RESULTS_PATH[0][1])
# Out:
# /Users/admin/Desktop/OGS_Catalog/catalogs/OGSCatalog/.txt/events/2024
# ...

# %%
reload(OGS_A)
print(args.target)
TargetCatalog = OGS_A.Target(args.target, args)
print(TargetCatalog.RESULTS_PATH[0][1])
# Out:
# /Users/admin/Desktop/OGS_Catalog/catalogs/OGS/events.csv
# Figure saved to /Users/admin/Desktop/Monica/PhD/OGS/img/eventsMap.png
# Figure saved to /Users/admin/Desktop/Monica/PhD/OGS/img/eventsDepths.png
# /Users/admin/Desktop/Monica/PhD/OGS/src/ogsplotter.py:232: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   self.ax.legend()
# Figure saved to /Users/admin/Desktop/Monica/PhD/OGS/img/eventsCumulativeEvents.png
# ...

# %%
compEvents = OGS_A.Comparison(args.base, args.target, args)
compEvents.compare()
# Out:
# Figure saved to /Users/admin/Desktop/Monica/PhD/OGS/img/eventsMap.png
# Figure saved to /Users/admin/Desktop/Monica/PhD/OGS/img/eventsDepths.png
# /Users/admin/Desktop/Monica/PhD/OGS/src/ogsplotter.py:232: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   self.ax.legend()
# Figure saved to /Users/admin/Desktop/Monica/PhD/OGS/img/eventsCumulativeEvents.png
# WARNING: No data found in .txt
# {}

# %%
import argparse
from pathlib import Path
from importlib import reload
from datetime import datetime

from sympy import comp

import ogscompare as OGS_A
args = argparse.Namespace(#base=Path('/Users/admin/Desktop/OGS_Catalog/catalogs/OGSCatalog/.txt/events/2024'),
                          base=Path('/Users/admin/Desktop/OGS_Catalog/catalogs/OGSCatalog/.dat/assignments/2024'),
                          #base=Path('/Users/admin/Desktop/OGS_Catalog/catalogs/OGSCatalog'),
                          dates=[datetime(2024, 3, 20, 0, 0), datetime(2024, 6, 20, 0, 0)],
                          station=Path('/Users/admin/Desktop/Monica/PhD/data/station'),
                          target=Path('/Users/admin/Desktop/OGS_Catalog/catalogs/OGS/assignments.csv'),
                          #target=Path('/Users/admin/Desktop/OGS_Catalog/catalogs/OGS/events.csv'),
                          #target=Path('/Users/admin/Desktop/OGS_Catalog/catalogs/OGS/NonLinLoc/events/'),
                          #target=Path('/Users/admin/Desktop/OGS_Catalog/catalogs/OGS/OGSMagnitude/events/'),
                          #target=Path('/Users/admin/Desktop/OGS_Catalog/catalogs/OGS/SeisBenchPicker/events/'),
                          #target=Path('/Users/admin/Desktop/OGS_Catalog/catalogs/OGS/GammaAssociator/events/'),
                          #target=Path('/Users/admin/Desktop/OGS_Catalog/catalogs/OGS/PyOctoAssociator/events/'),
                          waveform=Path('/Volumes/Expansion/KEN/waveforms'),
                          verbose=True)
compPicks = OGS_A.Comparison(args.base, args.target, args)
compPicks.compare()
# Out:
# /Users/admin/Desktop/Monica/PhD/OGS/src/ogsplotter.py:232: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   self.ax.legend()
# Figure saved to /Users/admin/Desktop/Monica/PhD/OGS/img/assignmentsCumulativePicks.png
# WARNING: No data found in .dat
# {}
